# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python-Object-Oriented-Programming-OOP-/blob/main/OOPS_Practice_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#NOTIFICATION QUEUE SYSTEM

from abc import ABC, abstractmethod

class Notification(ABC):
  @abstractmethod
  def send(self):
    pass

class Email(Notification):
  def send(self):
    print("Email Sent")

class SMS(Notification):
  def send(self):
    print('SMS Sent')

class Queue:
  def __init__(self):
    self.notifications = []

  def add(self,n):
    self.notifications.append(n)

  def process(self):
    for n in self.notifications:
      n.send()

q = Queue()

q.add(Email())
q.add(SMS())

q.process()
# Out:
# Email Sent
# SMS Sent

# %%
#FILE SYSTEM DESIGN

class File:
  def __init__(self,name):
    self.name = name

class Folder:
  def __init__(self,name):
    self.name = name
    self.contents = []

  def add (self,content):
    self.contents.append(content)

  def show(self):
    for c in self.contents:
      print(c.name)

# %%
#FOOD DELIVERY SYSTEM

class FoodItem:
  def __init__(self,name,price):
    self.name = name
    self.price = price

class Restaurant:
  def __init__(self, name):
    self.name = name
    self.menu = []

  def add_item(self,item):
    self.menu.append(item)

class Order:
  def __init__(self,user):
    self.user = user
    self.items = []

  def add_item(self, item):
    self.items.append(self,item)

  def total(self):
    return sum(i.price for i in self.items)

class User:
  def __init__(self):
    self.orders = []

  def place_order(self,order):
    self.orders.append(order)
    print("Order placed",order.total())

# %%
#ONLINE QUIZ SYSTEM

class Question:
  def __init__(self,text,answer):
    self.text = text
    self.answer = answer

class Quiz:
  def questions(self):
    self.questions = []

  def add_question(self,question):
    self.questions.append(question)

  def take(self):
    score = 0
    for q in self.questions:
      answer = input(q.text + ":")
      if answer == q.answer:
        score += 1
    print("Score",score)

# %%
#ONLINE MOVIE TICKET BOOKING

class Movie:
  def __init__(self,name):
    self.name = name

class show:
  def __init__(self,movie,seats):
    self.movie = movie
    self.seats = seats

  def book(self,show):
    if show.seats > 0:
      show.seats -= 1
      print("Ticket Booked")
