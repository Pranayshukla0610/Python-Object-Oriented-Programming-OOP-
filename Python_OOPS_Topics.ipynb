# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python-Object-Oriented-Programming-OOP-/blob/main/Python_OOPS_Topics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bank Account Systems

class Bank:
  def __init__(self,name,balance):
    self.name=name
    self.balance = balance

  def deposit(self,amount):
    self.balance += amount

  def withdraw(self,amount):
    if self.balance >= amount:
      self.balance -= amount
    else:
      print("Insufficient Balance")


  def display(self):
    print(self.name,self.balance)

acc = Bank("John",1000)
acc.deposit(5000)
acc.withdraw(2000)
acc.display()
# Out:
# John 4000

# %%
#Class vs Instance Variable

class Employee:
  company = "Google"

  def __init__(self,name):
    self.name = name

e1 = Employee('John')
e2 = Employee('Pranay')

print(e1.company,e2.company)
# Out:
# Google Google

# %%
#Encapsulation

class Account:
  def __init__(self,balance):
    self.__balance = balance

  def deposit(self,amount):
    self.__balance += amount

  def get_balance(self):
    return self.__balance

a = Account(10000000)
a.deposit(5000000)
a.get_balance()
# Out:
# 15000000

# %%
#Inheritence

class Animal:
  def speak(self):
    print("Animal Speaks")

class Dog(Animal):
  def bark(self):
    print("Dog barks")

class Cat(Animal):
  def meow(self):
    print("Cat meows")

d = Dog()
c = Cat()
d.speak()
c.speak()
d.bark()
c.meow()
# Out:
# Animal Speaks
# Animal Speaks
# Dog barks
# Cat meows

# %%
#Polymorphism

class Bird:
  def sound(self):
    print("Bird Sound")

class Sparrow(Bird):
  def sound(self):
    print("Sparrow Chirp")

class Crow(Bird):
  def sound(self):
    print("Crow Caw")

for bird in [Sparrow(),Crow()]:
  bird.sound()
# Out:
# Sparrow Chirp
# Crow Caw

# %%
#Abstraction

from abc import ABC, abstractmethod

class Vehicle:
  @abstractmethod
  def start(self):
    pass

class Car(Vehicle):
  def start(self):
    print("Car Starts")

c = Car()
c.start()
# Out:
# Car Starts
